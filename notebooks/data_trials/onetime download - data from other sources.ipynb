# %%
# !pip install histdata
# Out:
# Collecting histdata
#   Downloading histdata-1.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: requests in c:\users\abhis\miniconda3\envs\fools_gold\lib\site-packages (from histdata) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\abhis\miniconda3\envs\fools_gold\lib\site-packages (from histdata) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\abhis\miniconda3\envs\fools_gold\lib\site-packages (from beautifulsoup4->histdata) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhis\miniconda3\envs\fools_gold\lib\site-packages (from requests->histdata) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhis\miniconda3\envs\fools_gold\lib\site-packages (from requests->histdata) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abhis\miniconda3\envs\fools_gold\lib\site-packages (from requests->histdata) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abhis\miniconda3\envs\fools_gold\lib\site-packages (from requests->histdata) (2024.7.4)
# Downloading histdata-1.1-py3-none-any.whl (9.2 kB)
# Installing collected packages: histdata
# Successfully installed histdata-1.1

# %%
from histdata import download_hist_data as dl
from histdata.api import Platform as P, TimeFrame as TF

# %%
import csv
import os

from histdata.api import download_hist_data


def mkdir_p(path):
    import errno
    try:
        os.makedirs(path)
    except OSError as exc:
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:
            raise


def download_all():
    with open('pairs.csv', 'r') as f:
        reader = csv.reader(f, delimiter=',')
        next(reader, None)  # skip the headers
        for row in reader:
            currency_pair_name, pair, history_first_trading_month = row
            year = int(history_first_trading_month[0:4])
            print(currency_pair_name)
            output_folder = os.path.join('output', pair)
            mkdir_p(output_folder)
            try:
                while True:
                    could_download_full_year = False
                    try:
                        print('-', download_hist_data(year=year,
                                                      pair=pair,
                                                      output_directory=output_folder,
                                                      verbose=False))
                        could_download_full_year = True
                    except AssertionError:
                        pass  # lets download it month by month.
                    month = 1
                    while not could_download_full_year and month <= 12:
                        print('-', download_hist_data(year=str(year),
                                                      month=str(month),
                                                      pair=pair,
                                                      output_directory=output_folder,
                                                      verbose=False))
                        month += 1
                    year += 1
            except Exception:
                print('[DONE] for currency', currency_pair_name)


if __name__ == '__main__':
    download_all()
# Out:
# EUR/USD
# - output\eurusd\DAT_ASCII_EURUSD_M1_2000.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2001.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2002.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2003.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2004.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2005.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2006.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2007.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2008.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2009.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2010.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2011.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2012.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2013.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2014.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2015.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2016.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2017.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2018.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2019.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2020.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2021.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2022.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_2023.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_202401.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_202402.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_202403.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_202404.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_202405.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_202406.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_202407.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_202408.zip
# - output\eurusd\DAT_ASCII_EURUSD_M1_202409.zip
# [DONE] for currency EUR/USD
# EUR/CHF
# - output\eurchf\DAT_ASCII_EURCHF_M1_2002.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2003.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2004.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2005.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2006.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2007.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2008.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2009.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2010.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2011.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2012.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2013.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2014.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2015.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2016.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2017.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2018.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2019.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2020.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2021.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2022.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_2023.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_202401.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_202402.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_202403.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_202404.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_202405.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_202406.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_202407.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_202408.zip
# - output\eurchf\DAT_ASCII_EURCHF_M1_202409.zip
# [DONE] for currency EUR/CHF
# EUR/GBP
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2002.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2003.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2004.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2005.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2006.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2007.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2008.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2009.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2010.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2011.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2012.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2013.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2014.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2015.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2016.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2017.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2018.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2019.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2020.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2021.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2022.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_2023.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_202401.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_202402.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_202403.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_202404.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_202405.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_202406.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_202407.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_202408.zip
# - output\eurgbp\DAT_ASCII_EURGBP_M1_202409.zip
# [DONE] for currency EUR/GBP
# EUR/JPY
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2002.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2003.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2004.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2005.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2006.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2007.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2008.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2009.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2010.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2011.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2012.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2013.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2014.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2015.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2016.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2017.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2018.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2019.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2020.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2021.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2022.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_2023.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_202401.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_202402.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_202403.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_202404.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_202405.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_202406.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_202407.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_202408.zip
# - output\eurjpy\DAT_ASCII_EURJPY_M1_202409.zip
# [DONE] for currency EUR/JPY
# EUR/AUD
# - output\euraud\DAT_ASCII_EURAUD_M1_2002.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2003.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2004.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2005.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2006.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2007.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2008.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2009.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2010.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2011.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2012.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2013.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2014.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2015.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2016.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2017.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2018.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2019.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2020.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2021.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2022.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_2023.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_202401.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_202402.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_202403.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_202404.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_202405.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_202406.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_202407.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_202408.zip
# - output\euraud\DAT_ASCII_EURAUD_M1_202409.zip
# [DONE] for currency EUR/AUD
# USD/CAD
# - output\usdcad\DAT_ASCII_USDCAD_M1_2000.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2001.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2002.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2003.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2004.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2005.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2006.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2007.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2008.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2009.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2010.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2011.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2012.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2013.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2014.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2015.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2016.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2017.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2018.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2019.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2020.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2021.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2022.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_2023.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_202401.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_202402.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_202403.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_202404.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_202405.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_202406.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_202407.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_202408.zip
# - output\usdcad\DAT_ASCII_USDCAD_M1_202409.zip
# [DONE] for currency USD/CAD
# USD/CHF
# - output\usdchf\DAT_ASCII_USDCHF_M1_2000.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2001.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2002.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2003.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2004.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2005.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2006.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2007.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2008.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2009.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2010.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2011.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2012.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2013.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2014.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2015.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2016.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2017.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2018.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2019.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2020.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2021.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2022.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_2023.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_202401.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_202402.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_202403.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_202404.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_202405.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_202406.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_202407.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_202408.zip
# - output\usdchf\DAT_ASCII_USDCHF_M1_202409.zip
# [DONE] for currency USD/CHF
# USD/JPY
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2000.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2001.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2002.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2003.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2004.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2005.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2006.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2007.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2008.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2009.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2010.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2011.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2012.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2013.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2014.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2015.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2016.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2017.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2018.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2019.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2020.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2021.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2022.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_2023.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_202401.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_202402.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_202403.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_202404.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_202405.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_202406.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_202407.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_202408.zip
# - output\usdjpy\DAT_ASCII_USDJPY_M1_202409.zip
# [DONE] for currency USD/JPY
# USD/MXN
# - output\usdmxn\DAT_ASCII_USDMXN_M1_2010.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_2011.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_2012.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_2013.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_2014.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_2015.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_2016.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_2017.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_2018.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_2019.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_2020.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_2021.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_2022.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_2023.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_202401.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_202402.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_202403.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_202404.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_202405.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_202406.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_202407.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_202408.zip
# - output\usdmxn\DAT_ASCII_USDMXN_M1_202409.zip
# [DONE] for currency USD/MXN
# GBP/CHF
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2002.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2003.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2004.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2005.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2006.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2007.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2008.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2009.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2010.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2011.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2012.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2013.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2014.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2015.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2016.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2017.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2018.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2019.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2020.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2021.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2022.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_2023.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_202401.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_202402.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_202403.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_202404.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_202405.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_202406.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_202407.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_202408.zip
# - output\gbpchf\DAT_ASCII_GBPCHF_M1_202409.zip
# [DONE] for currency GBP/CHF
# GBP/JPY
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2002.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2003.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2004.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2005.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2006.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2007.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2008.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2009.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2010.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2011.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2012.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2013.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2014.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2015.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2016.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2017.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2018.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2019.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2020.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2021.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2022.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_2023.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_202401.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_202402.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_202403.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_202404.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_202405.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_202406.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_202407.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_202408.zip
# - output\gbpjpy\DAT_ASCII_GBPJPY_M1_202409.zip
# [DONE] for currency GBP/JPY
# GBP/USD
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2000.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2001.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2002.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2003.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2004.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2005.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2006.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2007.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2008.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2009.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2010.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2011.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2012.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2013.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2014.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2015.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2016.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2017.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2018.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2019.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2020.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2021.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2022.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_2023.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_202401.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_202402.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_202403.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_202404.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_202405.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_202406.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_202407.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_202408.zip
# - output\gbpusd\DAT_ASCII_GBPUSD_M1_202409.zip
# [DONE] for currency GBP/USD
# AUD/JPY
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2002.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2003.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2004.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2005.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2006.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2007.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2008.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2009.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2010.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2011.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2012.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2013.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2014.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2015.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2016.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2017.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2018.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2019.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2020.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2021.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2022.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_2023.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_202401.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_202402.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_202403.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_202404.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_202405.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_202406.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_202407.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_202408.zip
# - output\audjpy\DAT_ASCII_AUDJPY_M1_202409.zip
# [DONE] for currency AUD/JPY
# AUD/USD
# - output\audusd\DAT_ASCII_AUDUSD_M1_2000.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2001.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2002.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2003.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2004.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2005.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2006.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2007.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2008.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2009.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2010.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2011.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2012.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2013.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2014.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2015.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2016.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2017.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2018.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2019.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2020.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2021.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2022.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_2023.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_202401.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_202402.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_202403.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_202404.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_202405.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_202406.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_202407.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_202408.zip
# - output\audusd\DAT_ASCII_AUDUSD_M1_202409.zip
# [DONE] for currency AUD/USD
# CHF/JPY
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2002.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2003.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2004.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2005.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2006.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2007.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2008.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2009.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2010.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2011.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2012.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2013.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2014.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2015.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2016.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2017.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2018.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2019.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2020.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2021.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2022.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_2023.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_202401.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_202402.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_202403.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_202404.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_202405.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_202406.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_202407.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_202408.zip
# - output\chfjpy\DAT_ASCII_CHFJPY_M1_202409.zip
# [DONE] for currency CHF/JPY
# NZD/JPY
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2006.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2007.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2008.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2009.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2010.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2011.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2012.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2013.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2014.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2015.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2016.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2017.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2018.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2019.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2020.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2021.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2022.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_2023.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_202401.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_202402.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_202403.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_202404.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_202405.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_202406.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_202407.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_202408.zip
# - output\nzdjpy\DAT_ASCII_NZDJPY_M1_202409.zip
# [DONE] for currency NZD/JPY
# NZD/USD
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2005.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2006.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2007.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2008.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2009.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2010.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2011.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2012.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2013.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2014.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2015.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2016.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2017.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2018.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2019.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2020.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2021.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2022.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_2023.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_202401.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_202402.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_202403.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_202404.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_202405.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_202406.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_202407.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_202408.zip
# - output\nzdusd\DAT_ASCII_NZDUSD_M1_202409.zip
# [DONE] for currency NZD/USD
# XAU/USD
# - output\xauusd\DAT_ASCII_XAUUSD_M1_2009.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_2010.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_2011.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_2012.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_2013.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_2014.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_2015.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_2016.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_2017.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_2018.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_2019.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_2020.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_2021.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_2022.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_2023.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_202401.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_202402.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_202403.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_202404.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_202405.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_202406.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_202407.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_202408.zip
# - output\xauusd\DAT_ASCII_XAUUSD_M1_202409.zip
# [DONE] for currency XAU/USD
# EUR/CAD
# - output\eurcad\DAT_ASCII_EURCAD_M1_2007.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2008.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2009.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2010.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2011.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2012.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2013.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2014.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2015.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2016.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2017.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2018.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2019.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2020.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2021.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2022.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_2023.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_202401.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_202402.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_202403.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_202404.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_202405.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_202406.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_202407.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_202408.zip
# - output\eurcad\DAT_ASCII_EURCAD_M1_202409.zip
# [DONE] for currency EUR/CAD
# AUD/CAD
# - output\audcad\DAT_ASCII_AUDCAD_M1_2007.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2008.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2009.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2010.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2011.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2012.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2013.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2014.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2015.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2016.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2017.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2018.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2019.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2020.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2021.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2022.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_2023.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_202401.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_202402.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_202403.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_202404.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_202405.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_202406.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_202407.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_202408.zip
# - output\audcad\DAT_ASCII_AUDCAD_M1_202409.zip
# [DONE] for currency AUD/CAD
# CAD/JPY
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2007.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2008.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2009.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2010.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2011.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2012.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2013.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2014.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2015.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2016.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2017.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2018.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2019.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2020.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2021.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2022.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_2023.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_202401.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_202402.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_202403.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_202404.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_202405.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_202406.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_202407.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_202408.zip
# - output\cadjpy\DAT_ASCII_CADJPY_M1_202409.zip
# [DONE] for currency CAD/JPY
# EUR/NZD
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2008.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2009.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2010.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2011.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2012.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2013.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2014.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2015.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2016.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2017.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2018.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2019.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2020.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2021.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2022.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_2023.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_202401.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_202402.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_202403.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_202404.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_202405.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_202406.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_202407.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_202408.zip
# - output\eurnzd\DAT_ASCII_EURNZD_M1_202409.zip
# [DONE] for currency EUR/NZD
# GRX/EUR
# - output\grxeur\DAT_ASCII_GRXEUR_M1_2010.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_2011.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_2012.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_2013.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_2014.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_2015.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_2016.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_2017.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_2018.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_2019.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_2020.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_2021.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_2022.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_2023.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_202401.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_202402.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_202403.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_202404.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_202405.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_202406.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_202407.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_202408.zip
# - output\grxeur\DAT_ASCII_GRXEUR_M1_202409.zip
# [DONE] for currency GRX/EUR
# NZD/CAD
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2008.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2009.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2010.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2011.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2012.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2013.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2014.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2015.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2016.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2017.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2018.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2019.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2020.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2021.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2022.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_2023.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_202401.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_202402.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_202403.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_202404.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_202405.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_202406.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_202407.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_202408.zip
# - output\nzdcad\DAT_ASCII_NZDCAD_M1_202409.zip
# [DONE] for currency NZD/CAD
# SGD/JPY
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2008.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2009.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2010.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2011.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2012.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2013.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2014.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2015.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2016.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2017.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2018.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2019.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2020.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2021.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2022.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_2023.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_202401.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_202402.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_202403.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_202404.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_202405.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_202406.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_202407.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_202408.zip
# - output\sgdjpy\DAT_ASCII_SGDJPY_M1_202409.zip
# [DONE] for currency SGD/JPY
# USD/HKD
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2008.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2009.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2010.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2011.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2012.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2013.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2014.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2015.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2016.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2017.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2018.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2019.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2020.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2021.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2022.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_2023.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_202401.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_202402.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_202403.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_202404.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_202405.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_202406.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_202407.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_202408.zip
# - output\usdhkd\DAT_ASCII_USDHKD_M1_202409.zip
# [DONE] for currency USD/HKD
# USD/NOK
# - output\usdnok\DAT_ASCII_USDNOK_M1_2008.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_2009.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_2010.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_2011.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_2012.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_2013.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_2014.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_2015.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_2016.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_2017.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_2018.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_2019.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_2020.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_2021.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_2022.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_2023.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_202401.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_202402.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_202403.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_202404.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_202405.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_202406.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_202407.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_202408.zip
# - output\usdnok\DAT_ASCII_USDNOK_M1_202409.zip
# [DONE] for currency USD/NOK
# USD/TRY
# - output\usdtry\DAT_ASCII_USDTRY_M1_2010.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_2011.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_2012.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_2013.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_2014.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_2015.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_2016.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_2017.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_2018.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_2019.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_2020.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_2021.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_2022.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_2023.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_202401.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_202402.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_202403.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_202404.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_202405.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_202406.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_202407.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_202408.zip
# - output\usdtry\DAT_ASCII_USDTRY_M1_202409.zip
# [DONE] for currency USD/TRY
# XAU/AUD
# - output\xauaud\DAT_ASCII_XAUAUD_M1_2009.zip
# - output\xauaud\DAT_ASCII_XAUAUD_M1_2010.zip
# - output\xauaud\DAT_ASCII_XAUAUD_M1_2011.zip
# - output\xauaud\DAT_ASCII_XAUAUD_M1_2012.zip
# - output\xauaud\DAT_ASCII_XAUAUD_M1_2013.zip
# - output\xauaud\DAT_ASCII_XAUAUD_M1_2014.zip
# - output\xauaud\DAT_ASCII_XAUAUD_M1_2015.zip
# - output\xauaud\DAT_ASCII_XAUAUD_M1_2016.zip
# - output\xauaud\DAT_ASCII_XAUAUD_M1_2017.zip
# - output\xauaud\DAT_ASCII_XAUAUD_M1_2018.zip
# [DONE] for currency XAU/AUD
# AUD/CHF
# - output\audchf\DAT_ASCII_AUDCHF_M1_2008.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_2009.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_2010.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_2011.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_2012.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_2013.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_2014.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_2015.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_2016.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_2017.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_2018.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_2019.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_2020.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_2021.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_2022.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_2023.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_202401.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_202402.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_202403.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_202404.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_202405.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_202406.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_202407.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_202408.zip
# - output\audchf\DAT_ASCII_AUDCHF_M1_202409.zip
# [DONE] for currency AUD/CHF
# AUX/AUD
# - output\auxaud\DAT_ASCII_AUXAUD_M1_2010.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_2011.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_2012.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_2013.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_2014.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_2015.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_2016.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_2017.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_2018.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_2019.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_2020.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_2021.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_2022.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_2023.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_202401.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_202402.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_202403.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_202404.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_202405.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_202406.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_202407.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_202408.zip
# - output\auxaud\DAT_ASCII_AUXAUD_M1_202409.zip
# [DONE] for currency AUX/AUD
# EUR/HUF
# - output\eurhuf\DAT_ASCII_EURHUF_M1_2010.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_2011.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_2012.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_2013.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_2014.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_2015.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_2016.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_2017.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_2018.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_2019.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_2020.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_2021.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_2022.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_2023.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_202401.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_202402.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_202403.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_202404.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_202405.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_202406.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_202407.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_202408.zip
# - output\eurhuf\DAT_ASCII_EURHUF_M1_202409.zip
# [DONE] for currency EUR/HUF
# EUR/PLN
# - output\eurpln\DAT_ASCII_EURPLN_M1_2010.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_2011.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_2012.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_2013.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_2014.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_2015.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_2016.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_2017.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_2018.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_2019.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_2020.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_2021.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_2022.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_2023.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_202401.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_202402.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_202403.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_202404.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_202405.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_202406.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_202407.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_202408.zip
# - output\eurpln\DAT_ASCII_EURPLN_M1_202409.zip
# [DONE] for currency EUR/PLN
# FRX/EUR
# - output\frxeur\DAT_ASCII_FRXEUR_M1_2010.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_2011.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_2012.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_2013.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_2014.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_2015.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_2016.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_2017.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_2018.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_2019.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_2020.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_2021.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_2022.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_2023.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_202401.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_202402.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_202403.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_202404.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_202405.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_202406.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_202407.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_202408.zip
# - output\frxeur\DAT_ASCII_FRXEUR_M1_202409.zip
# [DONE] for currency FRX/EUR
# HKX/HKD
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_2010.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_2011.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_2012.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_2013.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_2014.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_2015.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_2016.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_2017.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_2018.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_2019.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_2020.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_2021.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_2022.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_2023.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_202401.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_202402.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_202403.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_202404.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_202405.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_202406.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_202407.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_202408.zip
# - output\hkxhkd\DAT_ASCII_HKXHKD_M1_202409.zip
# [DONE] for currency HKX/HKD
# NZD/CHF
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2008.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2009.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2010.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2011.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2012.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2013.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2014.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2015.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2016.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2017.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2018.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2019.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2020.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2021.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2022.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_2023.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_202401.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_202402.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_202403.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_202404.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_202405.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_202406.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_202407.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_202408.zip
# - output\nzdchf\DAT_ASCII_NZDCHF_M1_202409.zip
# [DONE] for currency NZD/CHF
# SPX/USD
# - output\spxusd\DAT_ASCII_SPXUSD_M1_2010.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_2011.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_2012.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_2013.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_2014.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_2015.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_2016.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_2017.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_2018.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_2019.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_2020.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_2021.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_2022.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_2023.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_202401.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_202402.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_202403.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_202404.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_202405.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_202406.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_202407.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_202408.zip
# - output\spxusd\DAT_ASCII_SPXUSD_M1_202409.zip
# [DONE] for currency SPX/USD
# USD/HUF
# - output\usdhuf\DAT_ASCII_USDHUF_M1_2010.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_2011.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_2012.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_2013.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_2014.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_2015.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_2016.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_2017.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_2018.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_2019.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_2020.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_2021.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_2022.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_2023.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_202401.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_202402.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_202403.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_202404.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_202405.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_202406.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_202407.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_202408.zip
# - output\usdhuf\DAT_ASCII_USDHUF_M1_202409.zip
# [DONE] for currency USD/HUF
# USD/PLN
# - output\usdpln\DAT_ASCII_USDPLN_M1_2010.zip
# - output\usdpln\DAT_ASCII_USDPLN_M1_2011.zip
# - output\usdpln\DAT_ASCII_USDPLN_M1_2012.zip
# ...
# - output\usdczk\DAT_ASCII_USDCZK_M1_202402.zip
# - output\usdczk\DAT_ASCII_USDCZK_M1_202403.zip
# - output\usdczk\DAT_ASCII_USDCZK_M1_202404.zip
# - output\usdczk\DAT_ASCII_USDCZK_M1_202405.zip
# - output\usdczk\DAT_ASCII_USDCZK_M1_202406.zip
# - output\usdczk\DAT_ASCII_USDCZK_M1_202407.zip
# - output\usdczk\DAT_ASCII_USDCZK_M1_202408.zip
# - output\usdczk\DAT_ASCII_USDCZK_M1_202409.zip
# [DONE] for currency USD/CZK
# USD/SEK
# - output\usdsek\DAT_ASCII_USDSEK_M1_2008.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_2009.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_2010.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_2011.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_2012.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_2013.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_2014.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_2015.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_2016.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_2017.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_2018.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_2019.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_2020.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_2021.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_2022.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_2023.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_202401.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_202402.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_202403.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_202404.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_202405.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_202406.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_202407.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_202408.zip
# - output\usdsek\DAT_ASCII_USDSEK_M1_202409.zip
# [DONE] for currency USD/SEK
# WTI/USD
# - output\wtiusd\DAT_ASCII_WTIUSD_M1_2010.zip
# - output\wtiusd\DAT_ASCII_WTIUSD_M1_2011.zip
# - output\wtiusd\DAT_ASCII_WTIUSD_M1_2012.zip
# - output\wtiusd\DAT_ASCII_WTIUSD_M1_2013.zip
# - output\wtiusd\DAT_ASCII_WTIUSD_M1_2014.zip
# - output\wtiusd\DAT_ASCII_WTIUSD_M1_2015.zip
# - output\wtiusd\DAT_ASCII_WTIUSD_M1_2016.zip
# - output\wtiusd\DAT_ASCII_WTIUSD_M1_2017.zip
# - output\wtiusd\DAT_ASCII_WTIUSD_M1_2018.zip
# - output\wtiusd\DAT_ASCII_WTIUSD_M1_2019.zip
# - output\wtiusd\DAT_ASCII_WTIUSD_M1_2020.zip
# - output\wtiusd\DAT_ASCII_WTIUSD_M1_2021.zip
# - output\wtiusd\DAT_ASCII_WTIUSD_M1_2022.zip
# - output\wtiusd\DAT_ASCII_WTIUSD_M1_2023.zip
# [DONE] for currency WTI/USD
# XAU/EUR
# - output\xaueur\DAT_ASCII_XAUEUR_M1_2009.zip
# - output\xaueur\DAT_ASCII_XAUEUR_M1_2010.zip
# - output\xaueur\DAT_ASCII_XAUEUR_M1_2011.zip
# - output\xaueur\DAT_ASCII_XAUEUR_M1_2012.zip
# - output\xaueur\DAT_ASCII_XAUEUR_M1_2013.zip
# - output\xaueur\DAT_ASCII_XAUEUR_M1_2014.zip
# - output\xaueur\DAT_ASCII_XAUEUR_M1_2015.zip
# - output\xaueur\DAT_ASCII_XAUEUR_M1_2016.zip
# - output\xaueur\DAT_ASCII_XAUEUR_M1_2017.zip
# - output\xaueur\DAT_ASCII_XAUEUR_M1_2018.zip
# [DONE] for currency XAU/EUR
# AUD/NZD
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2007.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2008.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2009.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2010.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2011.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2012.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2013.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2014.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2015.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2016.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2017.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2018.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2019.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2020.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2021.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2022.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_2023.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_202401.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_202402.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_202403.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_202404.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_202405.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_202406.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_202407.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_202408.zip
# - output\audnzd\DAT_ASCII_AUDNZD_M1_202409.zip
# [DONE] for currency AUD/NZD
# CAD/CHF
# - output\cadchf\DAT_ASCII_CADCHF_M1_2008.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_2009.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_2010.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_2011.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_2012.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_2013.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_2014.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_2015.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_2016.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_2017.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_2018.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_2019.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_2020.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_2021.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_2022.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_2023.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_202401.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_202402.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_202403.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_202404.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_202405.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_202406.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_202407.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_202408.zip
# - output\cadchf\DAT_ASCII_CADCHF_M1_202409.zip
# [DONE] for currency CAD/CHF
# EUR/DKK
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2008.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2009.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2010.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2011.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2012.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2013.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2014.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2015.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2016.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2017.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2018.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2019.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2020.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2021.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2022.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_2023.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_202401.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_202402.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_202403.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_202404.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_202405.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_202406.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_202407.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_202408.zip
# - output\eurdkk\DAT_ASCII_EURDKK_M1_202409.zip
# [DONE] for currency EUR/DKK
# EUR/NOK
# - output\eurnok\DAT_ASCII_EURNOK_M1_2008.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_2009.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_2010.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_2011.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_2012.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_2013.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_2014.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_2015.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_2016.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_2017.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_2018.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_2019.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_2020.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_2021.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_2022.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_2023.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_202401.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_202402.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_202403.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_202404.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_202405.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_202406.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_202407.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_202408.zip
# - output\eurnok\DAT_ASCII_EURNOK_M1_202409.zip
# [DONE] for currency EUR/NOK
# EUR/TRY
# - output\eurtry\DAT_ASCII_EURTRY_M1_2010.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_2011.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_2012.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_2013.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_2014.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_2015.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_2016.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_2017.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_2018.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_2019.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_2020.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_2021.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_2022.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_2023.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_202401.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_202402.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_202403.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_202404.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_202405.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_202406.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_202407.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_202408.zip
# - output\eurtry\DAT_ASCII_EURTRY_M1_202409.zip
# [DONE] for currency EUR/TRY
# GBP/CAD
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2007.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2008.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2009.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2010.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2011.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2012.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2013.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2014.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2015.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2016.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2017.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2018.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2019.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2020.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2021.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2022.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_2023.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_202401.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_202402.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_202403.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_202404.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_202405.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_202406.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_202407.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_202408.zip
# - output\gbpcad\DAT_ASCII_GBPCAD_M1_202409.zip
# [DONE] for currency GBP/CAD
# NSX/USD
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_2010.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_2011.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_2012.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_2013.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_2014.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_2015.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_2016.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_2017.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_2018.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_2019.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_2020.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_2021.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_2022.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_2023.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_202401.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_202402.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_202403.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_202404.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_202405.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_202406.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_202407.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_202408.zip
# - output\nsxusd\DAT_ASCII_NSXUSD_M1_202409.zip
# [DONE] for currency NSX/USD
# UKX/GBP
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_2010.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_2011.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_2012.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_2013.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_2014.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_2015.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_2016.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_2017.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_2018.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_2019.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_2020.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_2021.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_2022.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_2023.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_202401.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_202402.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_202403.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_202404.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_202405.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_202406.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_202407.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_202408.zip
# - output\ukxgbp\DAT_ASCII_UKXGBP_M1_202409.zip
# [DONE] for currency UKX/GBP
# USD/DKK
# - output\usddkk\DAT_ASCII_USDDKK_M1_2008.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_2009.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_2010.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_2011.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_2012.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_2013.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_2014.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_2015.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_2016.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_2017.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_2018.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_2019.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_2020.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_2021.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_2022.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_2023.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_202401.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_202402.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_202403.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_202404.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_202405.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_202406.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_202407.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_202408.zip
# - output\usddkk\DAT_ASCII_USDDKK_M1_202409.zip
# [DONE] for currency USD/DKK
# USD/SGD
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2008.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2009.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2010.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2011.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2012.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2013.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2014.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2015.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2016.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2017.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2018.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2019.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2020.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2021.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2022.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_2023.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_202401.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_202402.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_202403.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_202404.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_202405.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_202406.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_202407.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_202408.zip
# - output\usdsgd\DAT_ASCII_USDSGD_M1_202409.zip
# [DONE] for currency USD/SGD
# XAG/USD
# - output\xagusd\DAT_ASCII_XAGUSD_M1_2009.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_2010.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_2011.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_2012.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_2013.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_2014.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_2015.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_2016.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_2017.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_2018.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_2019.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_2020.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_2021.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_2022.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_2023.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_202401.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_202402.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_202403.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_202404.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_202405.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_202406.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_202407.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_202408.zip
# - output\xagusd\DAT_ASCII_XAGUSD_M1_202409.zip
# [DONE] for currency XAG/USD
# XAU/GBP
# - output\xaugbp\DAT_ASCII_XAUGBP_M1_2009.zip
# - output\xaugbp\DAT_ASCII_XAUGBP_M1_2010.zip
# - output\xaugbp\DAT_ASCII_XAUGBP_M1_2011.zip
# - output\xaugbp\DAT_ASCII_XAUGBP_M1_2012.zip
# - output\xaugbp\DAT_ASCII_XAUGBP_M1_2013.zip
# - output\xaugbp\DAT_ASCII_XAUGBP_M1_2014.zip
# - output\xaugbp\DAT_ASCII_XAUGBP_M1_2015.zip
# - output\xaugbp\DAT_ASCII_XAUGBP_M1_2016.zip
# - output\xaugbp\DAT_ASCII_XAUGBP_M1_2017.zip
# - output\xaugbp\DAT_ASCII_XAUGBP_M1_2018.zip
# [DONE] for currency XAU/GBP
